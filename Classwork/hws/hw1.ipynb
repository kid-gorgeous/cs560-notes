# %% [markdown]
# ### HW 1
# ---

# %%
import math

# %% [markdown]
# ### Question 1
#
# Please run the given buggy merge sort on array [5, 4, 9, 1] and demonstrate the merge process via a figure (like CLRS
# book Fig 2.3). Briefly state the bug and its fix (covered in 01/30’s lecture.)

# %%
arr=[5,4,9,1]
def merge(arr, p, q, r):
    L = arr[p:q]
    R = arr[q:r+1]
    L.append(math.inf)
    R.append(math.inf)

    i, j = 0, 0
    for k in range(p, r+1):
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
            
def mergeSort(arr, p, r):
    if p < r:
        q = (p+r) // 2

        mergeSort(arr, p, q)
        mergeSort(arr, q+1, r)
        merge(arr, p, q, r)
        
mergeSort(arr, 0,(len(arr)-1))
print(arr)
# Out:
# [4, 5, 9, 1]

# %% [markdown]
# ---

# %% [markdown]
# ### Question 2
#
# For the given array:
# ```python
# arr = [x for x in range(1<<10, 0, -1)]
# ```
#
# 1. Pass the array to an insertion sort function and record the total number of iterations the inner while loop executes.
#
# 2. Pass the array to a merge sort function (not the buggy one) and record the total number of iterations the for loop executes.
#
# 3. Change the array to `arr = [x for x in range(1<<12, 0, -1)]` and repeat the above two steps. Explain the change in terms of O(n * n) and O(n * lg n).

# %% [markdown]
# ##### Part 1:
# Pass the array to an insertion sort function and record the total number of iterations the inner while loop executes.

# %%
arr = [x for x in range(1<<10, 0, -1)]

# In class example of the Insertion Sort
def in_sort(arr:list):
    counter = 0
    
#   First loop: 
    for i in range(1,len(arr)):
        key = arr[i]
        j = i - 1
#       Second Loop:
        while(j >= 0 and arr[j] > key):
            arr[j+1] = arr[j]
            j-=1
            counter += 1
        key = arr[j+1]
        
    print("The amount of times the inner loop has been executed: ",counter)    
#     return arr
    pass

in_sort(arr)

def insertion_sort(arr):
    count = 0
    for i in range(1, len(arr)):
        key = arr[i]
        j = i - 1
        while j >= 0 and key < arr[j]:
            count += 1
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return count

arr = [x for x in range(1<<12,0,-1)]
count = insertion_sort(arr)
print("Total number of iterations:", count)
# Out:
# The amount of times the inner loop has been executed:  523776
# Total number of iterations: 8386560

# %% [markdown]
# ---
# ***Note to Grader***: I wasn't entirely sure where to approach this. The loop counter grew logorithicly of base 2 during each breadth search. So the output wasn't the total counted loops but instead a counter based on $log_{2}$ time.
#
# ##### Part 2:
# Pass the array to a merge sort function (not the buggy one) and record the total number of iterations the for loop executes.

# %%
def merge_sort(arr):
    count = 0

    if len(arr) > 1:
        mid = len(arr)//2
        L = arr[:mid]
        R = arr[mid:]

        count += merge_sort(L)
        count += merge_sort(R)

        i = j = k = 0

        while i < len(L) and j < len(R):
            count += 1
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1

        while i < len(L):
            count += 1
            arr[k] = L[i]
            i += 1
            k += 1

        while j < len(R):
            count += 1
            arr[k] = R[j]
            j += 1
            k += 1

    return count

arr = [x for x in range(1<<10,0,-1)]
arr1 = [x for x in range(1<<12,0,-1)]
count = merge_sort(arr)
count1 = merge_sort(arr1)
print("Total number of iterations:", count)
print("Total number of interations: ",count1)
# Out:
# Total number of iterations: 10240
# Total number of interations:  49152

# %% [markdown]
# ---
# ##### Part 3:

# %%
import math
arr = [x for x in range(1<< 12, 0, -1)] 

# Merge Sort example from Class
# Merge: arr, start, middle, endoL
# O(n)
def merge(arr, p, q, r):
    
    # CREATE ARRAYS
    left = arr[p:q + 1]    # a slice of the arr from p to q
    right = arr[q + 1:r + 1] # a slice of the arr from q + 1 to r + 1
    
    # SENTINEL characters????
    left.append(math.inf)
    right.append(math.inf)
    
    # INDEX 
    i,j = 0,0
    
    counter = 0
    # LOOP through the range and "merge" the arr
    for k in range(p, r + 1):
        counter +=1
        if(left[i] <= right[j]):
            arr[k] = left[i]
            i += 1

        else:
            arr[k] = right[j]
            j += 1
        
    print(counter)
        
# Merge Sort: arr, start, EOL
# O(n log n)
def mergeSort(arr, p, r):
    if(p < r):
        q = (p+r) // 2         # this is the reason it is considered O(n log n)
        
        
#       Sorts the first array
        mergeSort(arr, p, q)   # aT(n/b)
#       Sorts the second array
        mergeSort(arr, q+1, r) # D(n)
#       Merge the two arrays again
        merge(arr, p, q, r)    # C(n)
    
    
mergeSort(arr,0,(len(arr)-1))
# Out:
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 32
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 32
# 64
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 32
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 32
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 32
# 64
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 32
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# 16
# 2
# 2
# 4
# 2
# 2
# 4
# 8
# ...

# %% [markdown]
# ---
#
# ### Question 3: CLRS, Ch2 Problem 2.2 (Correctness of Bubble Sort)
#
# Bubble sort is a popular, but inefficient sorting algorithm. It works by repeatedly swapping adjacent elements that are out of order.
#
# ***a***. Let *A*' denote the output of BUBBLESORT(*A*). To prove that BUBBLESORT is correct, we need to prove that it terminates and that:
# - $A'[1] \leq A'[2] \leq ... \leq A'[n]$
#
# where *n = A.length*. In order to show that BUBBLESORT actually sorts, what else do we need to prove?
#
# - ***Initialization***:
# - ***Maintenance***:
# - ***Termination***:
#
# ***b***.
